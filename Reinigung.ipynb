# %% [markdown]
# ## Reinigung des Datensatzes *movies.csv*

# %% [markdown]
# **WICHTIGER HINWEIS:** Die Musterlösung bildet nur eine von vielen verschiedenen Lösungen ab. Gerade beim Thema Datenreinigung können viele unterschiedliche Ansätze verfolgt werden.

# %% [markdown]
# **Aufgabe 1**:
# Gehen Sie das Notebook Reinigung_Demo.ipynb noch einmal in Ruhe für sich durch. Es dient Ihnen beim Lösen der folgenden Aufgaben als Grundlage.

# %% [markdown]
# ### Vorbereitung

# %% [markdown]
# Sie arbeiten hier mit einem echten Datensatz. Der Datensatz stammt von der Filmdatenbank *imdb* und beinhaltet Netflix-Filme und TV-Shows. Der Datensatz kann hier heruntergeladen werden: https://www.kaggle.com/datasets/bharatnatrayn/movies-dataset-for-feature-extracion-prediction

# %% [markdown]
# **Aufgabe 2**:
# 1. Importieren Sie die Bibliothek pandas.
# 3. Lesen Sie den Datensatz movies.csv als DataFrame ein und speichern Sie ihn in einer Variable.
# 4. Schauen Sie sich den Datensatz an. Erinnerung: mit der head(5)-Funktion können Sie auch nur die ersten fünf Einträge anschauen. Schauen Sie sich auch an, was die info()-Funktion zurückliefert. Was für eine Dimension hat Ihr Datensatz? Was erfahren Sie über die einzelnen Spalten? Welche sind vollständig? Welche nicht? Wo fehlen wie viele Zellen? Notieren Sie Ihre Erkenntnisse in einer Markdown Zelle.
#
# **Fügen Sie beim Bearbeiten der einzelnen Aufgaben selber so viele neue Jupyter-Zellen ein, wie Sie benötigen. Schreiben Sie entweder direkt in den Code Kommentare (mit #) oder fügen Sie zwischendruch *Markdown*-Zellen ein, um Text zu verfassen.**

# %% [markdown]
# ### Teil 1: Duplikate

# %% [markdown]
# **Aufgabe 3**: Suchen Sie nach Duplikaten im DataFrame und entfernen Sie diese. Wie viel Duplikate gab es im DataFrame? Tipp: Berechnen Sie mit der Funktion len(dataFrame) die Grösse vor und nach dem Entfernen der Duplikate. Schreiben Sie in die Klammern der len()-Funktion den Namen Ihres DataFrame's.

# %% [markdown]
# ### Teil 2: Leere Zellen

# %% [markdown]
# **Aufgabe 4**: Schauen Sie sich die einzelnen Spalten des Datensatzes an und notieren Sie in einer Markdown-Zelle, was die Inhalte dieser Spalten aussagen. Dieser Schritt ist wichtig, bevor Sie nämlich in der nächsten Aufgabe die leeren Zellen auffüllen, müssen Sie verstehen, was überhaupt *in* diesen Zellen sein sollte.

# %% [markdown]
# **Aufgabe 5**: Füllen Sie die leeren Einträge im Datensatz durch eine geeignete Art auf. Schauen Sie sich die einzelnen Spalten an und entscheiden Sie bei jeder Spalte mit leeren Zellen, wie Sie vorgehen möchten. Begründen Sie Ihre Vorgehensweise für jede Spalte in einer Markdown-Zelle. Es gibt hier viele mögliche Lösungen und Vorgehensweisen.
#
# Falls Sie hier selbst nicht weiterkommen: Scrollen Sie ganz nach unten im Notebook. Dort hat es einen Vorschlag, wie Sie vorgehen können, um die leeren Zellen aufzufüllen.
#
# Nach der Bearbeitung dieser Aufgabe, sollten Sie keine einzige leere Zelle in Ihrem DataFrame mehr haben.

# %% [markdown]
# ### Teil 3: Falsches Format

# %% [markdown]
# **Aufgabe 6**: In der Spalte *YEAR* steht das Erscheinungsjahr oder die Erscheinungsjahre jeweils in Klammern. Diese Klammern möchten wir entfernen. Schauen Sie sich zuerst noch einmal die ersten fünf Zeilen des DataFrame's an, damit klar ist, was gemeint ist.
#
# Zum Entfernen rufen wir auf die Spalte *YEAR* im DataFrame *movies* die Funktion `str.strip('()')` auf. Das Ganze sieht dann so aus: `movies['YEAR'] = movies['YEAR'].str.strip('()')`

# %% [markdown]
# ### Teil 4: Falsche Daten

# %% [markdown]
# **Aufgabe 7**: Falls Ihnen beim Anschauen der Daten falsche Daten ins Auge springen, können Sie diese hier entfernen. Wenn Sie nichts feststellen, können Sie diesen Schritt überspringen.

# %% [markdown]
# ### Nachbereitung

# %% [markdown]
# **Aufgabe 8**: Speichern Sie die gereinigten Daten wieder als CSV-Datei ab. Fügen Sie an den Namen zusätzlich das Wort *_sauber* an.

# %% [markdown]
# ### Vorschlag zu Aufgabe 5

# %% [markdown]
# - YEAR: Löschen Sie alle Zeilen, welche beim YEAR keinen Eintrag haben
# - GENRE: Löschen Sie alle Zeilen, welche beim GENRE keinen Eintrag haben
# - RATING: Füllen Sie die leeren Einträge mit dem durchschnittlichen Wert dieser Spalte auf
# - VOTES: leere Einträge mit dem Wert 0 auffüllen
# - RunTime: Löschen Sie alle Zeilen, welche bei der RunTime keinen Eintrag haben
# - Gross: Füllen Sie die leeren Einträge mit dem Wert $0.0M auf
